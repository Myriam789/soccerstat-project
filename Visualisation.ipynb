# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv('top5-players_CLEANED.csv')

# %%
print("Duplicated rows:", data.duplicated().sum())
print("Missing values:\n", data.isnull().sum())
print("Negative minutes:", (data['Min'] < 0).sum())
print("Negative goals:", (data['Gls'] < 0).sum())
# Out:
# Duplicated rows: 0
# Missing values:
#  Rk             0
# Player         0
# Nation         1
# Pos            0
# Squad          0
# Comp           0
# Age            1
# Born           1
# MP             0
# Starts         0
# Min            0
# 90s            0
# Gls            0
# Ast            0
# G+A            0
# G-PK           0
# PK             0
# PKatt          0
# CrdY           0
# CrdR           0
# xG             0
# npxG           0
# xAG            0
# npxG+xAG       0
# PrgC           0
# PrgP           0
# PrgR           0
# Gls_90         0
# Ast_90         0
# G+A_90         0
# G-PK_90        0
# G+A-PK_90      0
# xG_90          0
# xAG_90         0
# xG+xAG_90      0
# npxG_90        0
# npxG+xAG_90    0
# dtype: int64
# Negative minutes: 0
# Negative goals: 0

# %%
positions = data['Pos'].dropna().str.split(',')
all_positions = [p.strip() for group in positions for p in group]
position_counts = pd.Series(all_positions).value_counts()

# %%
plt.figure(figsize=(8,5))
position_counts.plot(kind='bar', color='blue')
plt.title('Players by Position')
plt.xlabel('Position')
plt.ylabel('Number of Players')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
nation_counts = data['Nation'].value_counts().head(10)

# %%
plt.figure(figsize=(8,5))
nation_counts.plot(kind='bar', color='red')
plt.title('Players by Nation (Top 10)')
plt.xlabel('Nation')
plt.ylabel('Number of Players')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
